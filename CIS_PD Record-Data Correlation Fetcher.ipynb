# %%
import pandas as pd
import os
import boto3
import numpy as  np
import pandas as pd
import json
import time
from multiprocessing.dummy import Pool

# %%
os.chdir('//FS2\RTO\\CIS-PD MUSC\\')
client = boto3.client('athena', region_name = 'us-west-2')
user_id_pairings = pd.read_csv("decoded_forms\\videoID.csv")
subjenroll = pd.read_sas("subjenrollment.sas7bdat")
startstop = pd.read_csv("decoded_forms\\WatchStartStop.csv")

# set path to folder containing subject records
path = r'//FS2.smpp.local\\RTO\\CIS-PD Study\MJFF Curation\Finalized Dataset'
# set path to destination folder
dest = r'//FS2.smpp.local\\RTO\\CIS-PD Study\Patient Record Correlation'
#---------------------------------------------------------------------------------------------------------

# %%
# Medication Reports
table_med = 'Table10.csv'
dest_ext_med = 'Medication Reports'
file_name_med = 'med_timepoints.csv'

# Symptom Reports
table_symt = 'Table11.csv'
dest_ext_symt = 'Symptom Reports'
file_name_symt = 'symt_timepoints.csv'

# Diaries
table_diar = 'Table12.csv'
dest_ext_diar = 'Diaries'
file_name_diar = 'diar_timepoints.csv'

# Load Consolidated DataFrames
timepoints_med = pd.read_csv(os.path.join(dest, dest_ext_med, file_name_med), parse_dates = [1])
timepoints_symt = pd.read_csv(os.path.join(dest, dest_ext_symt, file_name_symt), parse_dates = [1])
timepoints_diar = pd.read_csv(os.path.join(dest, dest_ext_diar, file_name_diar), parse_dates = [1])

# %%
def user_id_4_to_6(user_id_4):
    
    # iterate through the rows of 'videoID.csv' file in 'decoded_forms' directory of 'CIS-PD MUSC' directory
    # file contains a column for both 4-digit and 6-digit subject ID
    for index, row in user_id_pairings.iterrows():
        if (int(row['SubjectCode']) == int(user_id_4)):
            
            # return 'None' if the SubjectCode (4-digit) has no corresponding 6-digit ID (Subj ID Athena cell in csv is empty)
            if np.isnan(row['Subj ID Athena']):
                return None
            
            # if a 6-digit code is contained within the row that has the 4-digit code, return it
            return int(row['Subj ID Athena'])
        
    # 'None' is returned if no row contains the 4-digit code
    return None

# %%
def generate_query(StartTimestamp, EndTimestamp, S6, S):
    template1 = "SELECT user_id-" + str(int(S6) - int(S)) + " AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z\n"
    template2 = "FROM watch_accelerometer\nwhere cohort != 'test'\nand user_id = "
    template3 = "\nand timestamp >= timestamp '"
    template4 = "'\nand timestamp < timestamp '"
    template5 = "'"
    
    startTime = str(StartTimestamp)
    endTime = str(EndTimestamp)
    
    query = template1 + template2 + S6 + template3 + startTime + template4 + endTime + template5
    
    # generate query from row in form509
    return query

# %%
def getTimestampsPaths(timepoints_med, timepoints_symt, timepoints_diar):
    
    # Initialize Empty Lists for Each Necessary Piece of Information from Each Record
    StartTimestamps = []
    EndTimestamps = []
    SaveFilePaths = []
    
    
    StartTimes = timepoints_med.apply(lambda row: row.Timestamp + pd.Timedelta(unit = 'minute', value = -30), axis = 1)
    EndTimes = timepoints_med.apply(lambda row: row.Timestamp + pd.Timedelta(unit = 'minute', value = 30), axis = 1)
    SavePaths = timepoints_med.apply(lambda row: os.path.join(dest, dest_ext_med, str(row.SubjID), 
                                                                                  str(row.Timestamp)[:7], 
                                                                                  str(row.Timestamp)[8:10],
                                                                                  str(row.Timestamp)[11:13] +
                                                                                  str(row.Timestamp)[14:16] +
                                                                                  str(row.Timestamp)[17:] + '.csv'), axis = 1)
    StartTimestamps = StartTimestamps + list(StartTimes)
    EndTimestamps = EndTimestamps + list(EndTimes)
    SaveFilePaths = SaveFilePaths + list(SavePaths)
    
    StartTimes = timepoints_symt.apply(lambda row: row.Timestamp + pd.Timedelta(unit = 'minute', value = -30), axis = 1)
    EndTimes = timepoints_symt.apply(lambda row: row.Timestamp, axis = 1)
    SavePaths = timepoints_symt.apply(lambda row: os.path.join(dest, dest_ext_symt, str(row.SubjID), 
                                                                                   str(row.Timestamp)[:7], 
                                                                                   str(row.Timestamp)[8:10],
                                                                                   str(row.Timestamp)[11:13] +
                                                                                   str(row.Timestamp)[14:16] +
                                                                                   str(row.Timestamp)[17:] + '.csv'),axis = 1)
    StartTimestamps = StartTimestamps + list(StartTimes)
    EndTimestamps = EndTimestamps + list(EndTimes)
    SaveFilePaths = SaveFilePaths + list(SavePaths)
    
    StartTimes = timepoints_diar.apply(lambda row: row.Timestamp + pd.Timedelta(unit = 'minute', value = -30), axis = 1)
    EndTimes = timepoints_diar.apply(lambda row: row.Timestamp, axis = 1)
    SavePaths = timepoints_diar.apply(lambda row: os.path.join(dest, dest_ext_diar, str(row.SubjID), 
                                                                                   str(row.Timestamp)[:7], 
                                                                                   str(row.Timestamp)[8:10],
                                                                                   str(row.Timestamp)[11:13] +
                                                                                   str(row.Timestamp)[14:16] +
                                                                                   str(row.Timestamp)[17:] + '.csv'),axis = 1)
    StartTimestamps = StartTimestamps + list(StartTimes)
    EndTimestamps = EndTimestamps + list(EndTimes)
    SaveFilePaths = SaveFilePaths + list(SavePaths)
    
    return StartTimestamps, EndTimestamps, SaveFilePaths

# %%
def iterate_reports(timepoints_med, timepoints_symt, timepoints_diar):
    
    StartTimestamps, EndTimestamps, SaveFilePaths = getTimestampsPaths(timepoints_med, timepoints_symt, timepoints_diar)
    
    # there is a new query (and also destination file paths) required for each patient report
    for s, e, p in zip(StartTimestamps, EndTimestamps, SaveFilePaths):
        
        # print the file path designation, beginning with the report type (including SubjID and full report time designation)
        print('          ' + p[63:])
        
        # get the 6-digit subject ID based on the text within the file path for each report
        if p[:81] == '//FS2.smpp.local\\\\RTO\\\\CIS-PD Study\\Patient Record Correlation\\Medication Reports':
            S = p[82:86]
            S6 = str(user_id_4_to_6(S))
        if p[:78] == '//FS2.smpp.local\\\\RTO\\\\CIS-PD Study\\Patient Record Correlation\\Symptom Reports':
            S = p[79:83]
            S6 = str(user_id_4_to_6(S))
        if p[:70] == '//FS2.smpp.local\\\\RTO\\\\CIS-PD Study\\Patient Record Correlation\\Diaries':
            S = p[71:75]
            S6 = str(user_id_4_to_6(S))
        
        # stop the function process if a 6-digit ID is not correlated (all 4-digit IDs targetted should have 6-digit IDs)
        if S6 == 'None':
            
            print('No 6-digit ID found.')
            break
            
        else:
            
            StartTimestamp = s
            EndTimestamp = e

            query = generate_query(StartTimestamp, EndTimestamp, S6, S)
            print(query)

# %%
# print the query for each report
iterate_reports(timepoints_med, timepoints_symt, timepoints_diar)
# Out:
#           Medication Reports\1004\2017-06\21\142217.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-21 13:52:17'
# and timestamp < timestamp '2017-06-21 14:52:17'
#           Medication Reports\1004\2017-06\21\152858.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-21 14:58:58'
# and timestamp < timestamp '2017-06-21 15:58:58'
#           Medication Reports\1004\2017-06\21\181225.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-21 17:42:25'
# and timestamp < timestamp '2017-06-21 18:42:25'
#           Medication Reports\1004\2017-06\21\210434.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-21 20:34:34'
# and timestamp < timestamp '2017-06-21 21:34:34'
#           Medication Reports\1004\2017-06\22\031524.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 02:45:24'
# and timestamp < timestamp '2017-06-22 03:45:24'
#           Medication Reports\1004\2017-06\22\100000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 09:30:00'
# and timestamp < timestamp '2017-06-22 10:30:00'
#           Medication Reports\1004\2017-06\22\110000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 10:30:00'
# and timestamp < timestamp '2017-06-22 11:30:00'
#           Medication Reports\1004\2017-06\22\125954.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 12:29:54'
# and timestamp < timestamp '2017-06-22 13:29:54'
#           Medication Reports\1004\2017-06\22\145829.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 14:28:29'
# and timestamp < timestamp '2017-06-22 15:28:29'
#           Medication Reports\1004\2017-06\22\192224.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 18:52:24'
# and timestamp < timestamp '2017-06-22 19:52:24'
#           Medication Reports\1004\2017-06\22\210700.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 20:37:00'
# and timestamp < timestamp '2017-06-22 21:37:00'
#           Medication Reports\1004\2017-06\23\000000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-22 23:30:00'
# and timestamp < timestamp '2017-06-23 00:30:00'
#           Medication Reports\1004\2017-06\23\030016.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-23 02:30:16'
# and timestamp < timestamp '2017-06-23 03:30:16'
#           Medication Reports\1004\2017-06\23\101146.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-23 09:41:46'
# and timestamp < timestamp '2017-06-23 10:41:46'
#           Medication Reports\1004\2017-06\23\151300.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-23 14:43:00'
# and timestamp < timestamp '2017-06-23 15:43:00'
#           Medication Reports\1004\2017-06\23\182900.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-23 17:59:00'
# and timestamp < timestamp '2017-06-23 18:59:00'
#           Medication Reports\1004\2017-06\23\200501.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-23 19:35:01'
# and timestamp < timestamp '2017-06-23 20:35:01'
#           Medication Reports\1004\2017-06\23\234032.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-23 23:10:32'
# and timestamp < timestamp '2017-06-24 00:10:32'
#           Medication Reports\1004\2017-06\24\105238.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-24 10:22:38'
# and timestamp < timestamp '2017-06-24 11:22:38'
#           Medication Reports\1004\2017-06\24\153442.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-24 15:04:42'
# and timestamp < timestamp '2017-06-24 16:04:42'
#           Medication Reports\1004\2017-06\24\175111.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-24 17:21:11'
# and timestamp < timestamp '2017-06-24 18:21:11'
#           Medication Reports\1004\2017-06\24\212703.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-24 20:57:03'
# and timestamp < timestamp '2017-06-24 21:57:03'
#           Medication Reports\1004\2017-06\25\104602.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-25 10:16:02'
# and timestamp < timestamp '2017-06-25 11:16:02'
#           Medication Reports\1004\2017-06\25\145135.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-25 14:21:35'
# and timestamp < timestamp '2017-06-25 15:21:35'
#           Medication Reports\1004\2017-06\25\180200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-25 17:32:00'
# and timestamp < timestamp '2017-06-25 18:32:00'
#           Medication Reports\1004\2017-06\25\210200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-25 20:32:00'
# and timestamp < timestamp '2017-06-25 21:32:00'
#           Medication Reports\1004\2017-06\26\090848.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-26 08:38:48'
# and timestamp < timestamp '2017-06-26 09:38:48'
#           Medication Reports\1004\2017-06\26\181832.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-26 17:48:32'
# and timestamp < timestamp '2017-06-26 18:48:32'
#           Medication Reports\1004\2017-06\26\210008.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-26 20:30:08'
# and timestamp < timestamp '2017-06-26 21:30:08'
#           Medication Reports\1004\2017-06\27\000000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-26 23:30:00'
# and timestamp < timestamp '2017-06-27 00:30:00'
#           Medication Reports\1004\2017-06\27\111131.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-27 10:41:31'
# and timestamp < timestamp '2017-06-27 11:41:31'
#           Medication Reports\1004\2017-06\27\145113.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-27 14:21:13'
# and timestamp < timestamp '2017-06-27 15:21:13'
#           Medication Reports\1004\2017-06\27\183102.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-27 18:01:02'
# and timestamp < timestamp '2017-06-27 19:01:02'
#           Medication Reports\1004\2017-06\27\211144.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-27 20:41:44'
# and timestamp < timestamp '2017-06-27 21:41:44'
#           Medication Reports\1004\2017-06\28\000730.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-27 23:37:30'
# and timestamp < timestamp '2017-06-28 00:37:30'
#           Medication Reports\1004\2017-06\28\113617.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-28 11:06:17'
# and timestamp < timestamp '2017-06-28 12:06:17'
#           Medication Reports\1004\2017-06\28\145026.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-28 14:20:26'
# and timestamp < timestamp '2017-06-28 15:20:26'
#           Medication Reports\1004\2017-06\28\175050.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-28 17:20:50'
# and timestamp < timestamp '2017-06-28 18:20:50'
#           Medication Reports\1004\2017-06\28\204233.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-28 20:12:33'
# and timestamp < timestamp '2017-06-28 21:12:33'
#           Medication Reports\1004\2017-06\28\235250.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-28 23:22:50'
# and timestamp < timestamp '2017-06-29 00:22:50'
#           Medication Reports\1004\2017-06\29\044848.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-29 04:18:48'
# and timestamp < timestamp '2017-06-29 05:18:48'
#           Medication Reports\1004\2017-06\29\110026.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-29 10:30:26'
# and timestamp < timestamp '2017-06-29 11:30:26'
#           Medication Reports\1004\2017-06\29\144100.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-29 14:11:00'
# and timestamp < timestamp '2017-06-29 15:11:00'
#           Medication Reports\1004\2017-06\29\184600.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-29 18:16:00'
# and timestamp < timestamp '2017-06-29 19:16:00'
#           Medication Reports\1004\2017-06\29\214351.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-29 21:13:51'
# and timestamp < timestamp '2017-06-29 22:13:51'
#           Medication Reports\1004\2017-06\30\003322.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-30 00:03:22'
# and timestamp < timestamp '2017-06-30 01:03:22'
#           Medication Reports\1004\2017-06\30\103000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-30 10:00:00'
# and timestamp < timestamp '2017-06-30 11:00:00'
#           Medication Reports\1004\2017-06\30\140049.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-30 13:30:49'
# and timestamp < timestamp '2017-06-30 14:30:49'
#           Medication Reports\1004\2017-06\30\173000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-30 17:00:00'
# and timestamp < timestamp '2017-06-30 18:00:00'
#           Medication Reports\1004\2017-06\30\211115.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-30 20:41:15'
# and timestamp < timestamp '2017-06-30 21:41:15'
#           Medication Reports\1004\2017-07\01\000111.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-06-30 23:31:11'
# and timestamp < timestamp '2017-07-01 00:31:11'
#           Medication Reports\1004\2017-07\01\094900.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-01 09:19:00'
# and timestamp < timestamp '2017-07-01 10:19:00'
#           Medication Reports\1004\2017-07\01\141232.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-01 13:42:32'
# and timestamp < timestamp '2017-07-01 14:42:32'
#           Medication Reports\1004\2017-07\01\180118.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-01 17:31:18'
# and timestamp < timestamp '2017-07-01 18:31:18'
#           Medication Reports\1004\2017-07\01\205653.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-01 20:26:53'
# and timestamp < timestamp '2017-07-01 21:26:53'
#           Medication Reports\1004\2017-07\02\095400.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-02 09:24:00'
# and timestamp < timestamp '2017-07-02 10:24:00'
#           Medication Reports\1004\2017-07\02\143000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-02 14:00:00'
# and timestamp < timestamp '2017-07-02 15:00:00'
#           Medication Reports\1004\2017-07\02\180110.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-02 17:31:10'
# and timestamp < timestamp '2017-07-02 18:31:10'
#           Medication Reports\1004\2017-07\02\212243.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-02 20:52:43'
# and timestamp < timestamp '2017-07-02 21:52:43'
#           Medication Reports\1004\2017-07\03\002325.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-02 23:53:25'
# and timestamp < timestamp '2017-07-03 00:53:25'
#           Medication Reports\1004\2017-07\03\101731.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-03 09:47:31'
# and timestamp < timestamp '2017-07-03 10:47:31'
#           Medication Reports\1004\2017-07\03\171822.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-03 16:48:22'
# and timestamp < timestamp '2017-07-03 17:48:22'
#           Medication Reports\1004\2017-07\04\000320.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-03 23:33:20'
# and timestamp < timestamp '2017-07-04 00:33:20'
#           Medication Reports\1004\2017-07\04\030130.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 02:31:30'
# and timestamp < timestamp '2017-07-04 03:31:30'
#           Medication Reports\1004\2017-07\04\091600.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 08:46:00'
# and timestamp < timestamp '2017-07-04 09:46:00'
#           Medication Reports\1004\2017-07\04\095600.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 09:26:00'
# and timestamp < timestamp '2017-07-04 10:26:00'
#           Medication Reports\1004\2017-07\04\115533.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 11:25:33'
# and timestamp < timestamp '2017-07-04 12:25:33'
#           Medication Reports\1004\2017-07\04\150000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 14:30:00'
# and timestamp < timestamp '2017-07-04 15:30:00'
#           Medication Reports\1004\2017-07\04\152600.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 14:56:00'
# and timestamp < timestamp '2017-07-04 15:56:00'
#           Medication Reports\1004\2017-07\04\180020.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 17:30:20'
# and timestamp < timestamp '2017-07-04 18:30:20'
#           Medication Reports\1004\2017-07\04\213400.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 21:04:00'
# and timestamp < timestamp '2017-07-04 22:04:00'
#           Medication Reports\1004\2017-07\05\000302.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-04 23:33:02'
# and timestamp < timestamp '2017-07-05 00:33:02'
#           Medication Reports\1004\2017-07\05\070032.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-05 06:30:32'
# and timestamp < timestamp '2017-07-05 07:30:32'
#           Medication Reports\1004\2017-07\05\123016.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-05 12:00:16'
# and timestamp < timestamp '2017-07-05 13:00:16'
#           Medication Reports\1004\2017-07\05\130020.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-05 12:30:20'
# and timestamp < timestamp '2017-07-05 13:30:20'
#           Medication Reports\1004\2017-07\05\210200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-05 20:32:00'
# and timestamp < timestamp '2017-07-05 21:32:00'
#           Medication Reports\1004\2017-07\05\213800.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-05 21:08:00'
# and timestamp < timestamp '2017-07-05 22:08:00'
#           Medication Reports\1004\2017-07\06\000155.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-05 23:31:55'
# and timestamp < timestamp '2017-07-06 00:31:55'
#           Medication Reports\1004\2017-07\06\090857.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-06 08:38:57'
# and timestamp < timestamp '2017-07-06 09:38:57'
#           Medication Reports\1004\2017-07\06\130000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-06 12:30:00'
# and timestamp < timestamp '2017-07-06 13:30:00'
#           Medication Reports\1004\2017-07\06\134900.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-06 13:19:00'
# and timestamp < timestamp '2017-07-06 14:19:00'
#           Medication Reports\1004\2017-07\06\171000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-06 16:40:00'
# and timestamp < timestamp '2017-07-06 17:40:00'
#           Medication Reports\1004\2017-07\06\181033.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-06 17:40:33'
# and timestamp < timestamp '2017-07-06 18:40:33'
#           Medication Reports\1004\2017-07\06\205000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-06 20:20:00'
# and timestamp < timestamp '2017-07-06 21:20:00'
#           Medication Reports\1004\2017-07\06\210000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-06 20:30:00'
# and timestamp < timestamp '2017-07-06 21:30:00'
#           Medication Reports\1004\2017-07\07\135828.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-07 13:28:28'
# and timestamp < timestamp '2017-07-07 14:28:28'
#           Medication Reports\1004\2017-07\07\162444.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-07 15:54:44'
# and timestamp < timestamp '2017-07-07 16:54:44'
#           Medication Reports\1004\2017-07\07\173911.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-07 17:09:11'
# and timestamp < timestamp '2017-07-07 18:09:11'
#           Medication Reports\1004\2017-07\07\210121.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-07 20:31:21'
# and timestamp < timestamp '2017-07-07 21:31:21'
#           Medication Reports\1004\2017-07\08\011735.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-08 00:47:35'
# and timestamp < timestamp '2017-07-08 01:47:35'
#           Medication Reports\1004\2017-07\08\083817.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-08 08:08:17'
# and timestamp < timestamp '2017-07-08 09:08:17'
#           Medication Reports\1004\2017-07\08\131221.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-08 12:42:21'
# and timestamp < timestamp '2017-07-08 13:42:21'
#           Medication Reports\1004\2017-07\08\164227.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-08 16:12:27'
# and timestamp < timestamp '2017-07-08 17:12:27'
#           Medication Reports\1004\2017-07\08\204705.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-08 20:17:05'
# and timestamp < timestamp '2017-07-08 21:17:05'
#           Medication Reports\1004\2017-07\09\083000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-09 08:00:00'
# and timestamp < timestamp '2017-07-09 09:00:00'
#           Medication Reports\1004\2017-07\09\095133.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-09 09:21:33'
# and timestamp < timestamp '2017-07-09 10:21:33'
#           Medication Reports\1004\2017-07\09\131047.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-09 12:40:47'
# and timestamp < timestamp '2017-07-09 13:40:47'
#           Medication Reports\1004\2017-07\09\173100.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-09 17:01:00'
# and timestamp < timestamp '2017-07-09 18:01:00'
#           Medication Reports\1004\2017-07\09\173900.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-09 17:09:00'
# and timestamp < timestamp '2017-07-09 18:09:00'
#           Medication Reports\1004\2017-07\09\222300.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-09 21:53:00'
# and timestamp < timestamp '2017-07-09 22:53:00'
#           Medication Reports\1004\2017-07\10\020603.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-10 01:36:03'
# and timestamp < timestamp '2017-07-10 02:36:03'
#           Medication Reports\1004\2017-07\10\094000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-10 09:10:00'
# and timestamp < timestamp '2017-07-10 10:10:00'
#           Medication Reports\1004\2017-07\10\130000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-10 12:30:00'
# and timestamp < timestamp '2017-07-10 13:30:00'
#           Medication Reports\1004\2017-07\10\170000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-10 16:30:00'
# and timestamp < timestamp '2017-07-10 17:30:00'
#           Medication Reports\1004\2017-07\10\184154.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-10 18:11:54'
# and timestamp < timestamp '2017-07-10 19:11:54'
#           Medication Reports\1004\2017-07\11\005100.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-11 00:21:00'
# and timestamp < timestamp '2017-07-11 01:21:00'
#           Medication Reports\1004\2017-07\11\090000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-11 08:30:00'
# and timestamp < timestamp '2017-07-11 09:30:00'
#           Medication Reports\1004\2017-07\11\130800.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-11 12:38:00'
# and timestamp < timestamp '2017-07-11 13:38:00'
#           Medication Reports\1004\2017-07\11\171837.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-11 16:48:37'
# and timestamp < timestamp '2017-07-11 17:48:37'
#           Medication Reports\1004\2017-07\11\204900.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-11 20:19:00'
# and timestamp < timestamp '2017-07-11 21:19:00'
#           Medication Reports\1004\2017-07\12\090957.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-12 08:39:57'
# and timestamp < timestamp '2017-07-12 09:39:57'
#           Medication Reports\1004\2017-07\12\130000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-12 12:30:00'
# and timestamp < timestamp '2017-07-12 13:30:00'
#           Medication Reports\1004\2017-07\12\171022.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-12 16:40:22'
# and timestamp < timestamp '2017-07-12 17:40:22'
#           Medication Reports\1004\2017-07\13\084200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-13 08:12:00'
# and timestamp < timestamp '2017-07-13 09:12:00'
#           Medication Reports\1004\2017-07\13\130000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-13 12:30:00'
# and timestamp < timestamp '2017-07-13 13:30:00'
#           Medication Reports\1004\2017-07\13\164806.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-13 16:18:06'
# and timestamp < timestamp '2017-07-13 17:18:06'
#           Medication Reports\1004\2017-07\13\213156.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-13 21:01:56'
# and timestamp < timestamp '2017-07-13 22:01:56'
#           Medication Reports\1004\2017-07\14\005208.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-14 00:22:08'
# and timestamp < timestamp '2017-07-14 01:22:08'
#           Medication Reports\1004\2017-07\14\074200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-14 07:12:00'
# and timestamp < timestamp '2017-07-14 08:12:00'
#           Medication Reports\1004\2017-07\14\120000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-14 11:30:00'
# and timestamp < timestamp '2017-07-14 12:30:00'
#           Medication Reports\1004\2017-07\14\154511.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-14 15:15:11'
# and timestamp < timestamp '2017-07-14 16:15:11'
#           Medication Reports\1004\2017-07\14\165203.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-14 16:22:03'
# and timestamp < timestamp '2017-07-14 17:22:03'
#           Medication Reports\1004\2017-07\14\205459.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-14 20:24:59'
# and timestamp < timestamp '2017-07-14 21:24:59'
#           Medication Reports\1004\2017-07\15\010855.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-15 00:38:55'
# and timestamp < timestamp '2017-07-15 01:38:55'
#           Medication Reports\1004\2017-07\15\060446.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-15 05:34:46'
# and timestamp < timestamp '2017-07-15 06:34:46'
#           Medication Reports\1004\2017-07\15\135331.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-15 13:23:31'
# and timestamp < timestamp '2017-07-15 14:23:31'
#           Medication Reports\1004\2017-07\15\172600.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-15 16:56:00'
# and timestamp < timestamp '2017-07-15 17:56:00'
#           Medication Reports\1004\2017-07\15\210920.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-15 20:39:20'
# and timestamp < timestamp '2017-07-15 21:39:20'
#           Medication Reports\1004\2017-07\16\005552.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-16 00:25:52'
# and timestamp < timestamp '2017-07-16 01:25:52'
#           Medication Reports\1004\2017-07\16\021048.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-16 01:40:48'
# and timestamp < timestamp '2017-07-16 02:40:48'
#           Medication Reports\1004\2017-07\16\084200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-16 08:12:00'
# and timestamp < timestamp '2017-07-16 09:12:00'
#           Medication Reports\1004\2017-07\16\124525.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-16 12:15:25'
# and timestamp < timestamp '2017-07-16 13:15:25'
#           Medication Reports\1004\2017-07\16\214346.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-16 21:13:46'
# and timestamp < timestamp '2017-07-16 22:13:46'
#           Medication Reports\1004\2017-07\17\015536.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-17 01:25:36'
# and timestamp < timestamp '2017-07-17 02:25:36'
#           Medication Reports\1004\2017-07\17\073200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-17 07:02:00'
# and timestamp < timestamp '2017-07-17 08:02:00'
#           Medication Reports\1004\2017-07\17\124539.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-17 12:15:39'
# and timestamp < timestamp '2017-07-17 13:15:39'
#           Medication Reports\1004\2017-07\17\165900.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-17 16:29:00'
# and timestamp < timestamp '2017-07-17 17:29:00'
#           Medication Reports\1004\2017-07\17\211806.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-17 20:48:06'
# and timestamp < timestamp '2017-07-17 21:48:06'
#           Medication Reports\1004\2017-07\18\003632.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-18 00:06:32'
# and timestamp < timestamp '2017-07-18 01:06:32'
#           Medication Reports\1004\2017-07\18\071103.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-18 06:41:03'
# and timestamp < timestamp '2017-07-18 07:41:03'
#           Medication Reports\1004\2017-07\18\115123.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-18 11:21:23'
# and timestamp < timestamp '2017-07-18 12:21:23'
#           Medication Reports\1004\2017-07\18\172906.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-18 16:59:06'
# and timestamp < timestamp '2017-07-18 17:59:06'
#           Medication Reports\1004\2017-07\18\210800.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-18 20:38:00'
# and timestamp < timestamp '2017-07-18 21:38:00'
#           Medication Reports\1004\2017-07\19\004115.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-19 00:11:15'
# and timestamp < timestamp '2017-07-19 01:11:15'
#           Medication Reports\1004\2017-07\19\090400.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-19 08:34:00'
# and timestamp < timestamp '2017-07-19 09:34:00'
#           Medication Reports\1004\2017-07\19\161032.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-19 15:40:32'
# and timestamp < timestamp '2017-07-19 16:40:32'
#           Medication Reports\1004\2017-07\19\202941.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-19 19:59:41'
# and timestamp < timestamp '2017-07-19 20:59:41'
#           Medication Reports\1004\2017-07\19\204700.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-19 20:17:00'
# and timestamp < timestamp '2017-07-19 21:17:00'
#           Medication Reports\1004\2017-07\20\003324.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-20 00:03:24'
# and timestamp < timestamp '2017-07-20 01:03:24'
#           Medication Reports\1004\2017-07\20\070000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-20 06:30:00'
# and timestamp < timestamp '2017-07-20 07:30:00'
#           Medication Reports\1004\2017-07\20\115900.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-20 11:29:00'
# and timestamp < timestamp '2017-07-20 12:29:00'
#           Medication Reports\1004\2017-07\20\162200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-20 15:52:00'
# and timestamp < timestamp '2017-07-20 16:52:00'
#           Medication Reports\1004\2017-07\21\030948.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-21 02:39:48'
# and timestamp < timestamp '2017-07-21 03:39:48'
#           Medication Reports\1004\2017-07\21\081000.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-21 07:40:00'
# and timestamp < timestamp '2017-07-21 08:40:00'
#           Medication Reports\1004\2017-07\21\131036.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-21 12:40:36'
# and timestamp < timestamp '2017-07-21 13:40:36'
#           Medication Reports\1004\2017-07\21\163300.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-21 16:03:00'
# and timestamp < timestamp '2017-07-21 17:03:00'
#           Medication Reports\1004\2017-07\21\223200.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-21 22:02:00'
# and timestamp < timestamp '2017-07-21 23:02:00'
#           Medication Reports\1004\2017-07\22\003338.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-22 00:03:38'
# and timestamp < timestamp '2017-07-22 01:03:38'
#           Medication Reports\1004\2017-07\22\033416.csv
# SELECT user_id-141575 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142579
# and timestamp >= timestamp '2017-07-22 03:04:16'
# ...
# and user_id = 142622
# and timestamp >= timestamp '2017-07-31 12:32:16'
# and timestamp < timestamp '2017-07-31 13:32:16'
#           Medication Reports\1039\2017-07\31\160107.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-07-31 15:31:07'
# and timestamp < timestamp '2017-07-31 16:31:07'
#           Medication Reports\1039\2017-07\31\210005.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-07-31 20:30:05'
# and timestamp < timestamp '2017-07-31 21:30:05'
#           Medication Reports\1039\2017-08\01\013511.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-01 01:05:11'
# and timestamp < timestamp '2017-08-01 02:05:11'
#           Medication Reports\1039\2017-08\01\025751.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-01 02:27:51'
# and timestamp < timestamp '2017-08-01 03:27:51'
#           Medication Reports\1039\2017-08\01\103030.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-01 10:00:30'
# and timestamp < timestamp '2017-08-01 11:00:30'
#           Medication Reports\1039\2017-08\01\133523.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-01 13:05:23'
# and timestamp < timestamp '2017-08-01 14:05:23'
#           Medication Reports\1039\2017-08\01\161329.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-01 15:43:29'
# and timestamp < timestamp '2017-08-01 16:43:29'
#           Medication Reports\1039\2017-08\01\210101.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-01 20:31:01'
# and timestamp < timestamp '2017-08-01 21:31:01'
#           Medication Reports\1039\2017-08\02\003550.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-02 00:05:50'
# and timestamp < timestamp '2017-08-02 01:05:50'
#           Medication Reports\1039\2017-08\02\023706.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-02 02:07:06'
# and timestamp < timestamp '2017-08-02 03:07:06'
#           Medication Reports\1039\2017-08\02\102737.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-02 09:57:37'
# and timestamp < timestamp '2017-08-02 10:57:37'
#           Medication Reports\1039\2017-08\02\131420.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-02 12:44:20'
# and timestamp < timestamp '2017-08-02 13:44:20'
#           Medication Reports\1039\2017-08\02\161300.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-02 15:43:00'
# and timestamp < timestamp '2017-08-02 16:43:00'
#           Medication Reports\1039\2017-08\02\211447.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-02 20:44:47'
# and timestamp < timestamp '2017-08-02 21:44:47'
#           Medication Reports\1039\2017-08\03\003344.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-03 00:03:44'
# and timestamp < timestamp '2017-08-03 01:03:44'
#           Medication Reports\1039\2017-08\03\015037.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-03 01:20:37'
# and timestamp < timestamp '2017-08-03 02:20:37'
#           Medication Reports\1039\2017-08\03\152140.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-03 14:51:40'
# and timestamp < timestamp '2017-08-03 15:51:40'
#           Medication Reports\1039\2017-08\03\193040.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-03 19:00:40'
# and timestamp < timestamp '2017-08-03 20:00:40'
#           Medication Reports\1039\2017-08\03\224618.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-03 22:16:18'
# and timestamp < timestamp '2017-08-03 23:16:18'
#           Medication Reports\1039\2017-08\04\015405.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-04 01:24:05'
# and timestamp < timestamp '2017-08-04 02:24:05'
#           Medication Reports\1039\2017-08\04\101111.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-04 09:41:11'
# and timestamp < timestamp '2017-08-04 10:41:11'
#           Medication Reports\1039\2017-08\04\143110.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-04 14:01:10'
# and timestamp < timestamp '2017-08-04 15:01:10'
#           Medication Reports\1039\2017-08\04\191927.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-04 18:49:27'
# and timestamp < timestamp '2017-08-04 19:49:27'
#           Medication Reports\1039\2017-08\04\224523.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-04 22:15:23'
# and timestamp < timestamp '2017-08-04 23:15:23'
#           Medication Reports\1039\2017-08\05\022112.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-05 01:51:12'
# and timestamp < timestamp '2017-08-05 02:51:12'
#           Medication Reports\1039\2017-08\05\125057.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-05 12:20:57'
# and timestamp < timestamp '2017-08-05 13:20:57'
#           Medication Reports\1039\2017-08\05\131517.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-05 12:45:17'
# and timestamp < timestamp '2017-08-05 13:45:17'
#           Medication Reports\1039\2017-08\05\145531.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-05 14:25:31'
# and timestamp < timestamp '2017-08-05 15:25:31'
#           Medication Reports\1039\2017-08\05\184841.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-05 18:18:41'
# and timestamp < timestamp '2017-08-05 19:18:41'
#           Medication Reports\1039\2017-08\05\205551.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-05 20:25:51'
# and timestamp < timestamp '2017-08-05 21:25:51'
#           Medication Reports\1039\2017-08\06\010731.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-06 00:37:31'
# and timestamp < timestamp '2017-08-06 01:37:31'
#           Medication Reports\1039\2017-08\06\025101.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-06 02:21:01'
# and timestamp < timestamp '2017-08-06 03:21:01'
#           Medication Reports\1039\2017-08\06\120931.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-06 11:39:31'
# and timestamp < timestamp '2017-08-06 12:39:31'
#           Medication Reports\1039\2017-08\06\130123.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-06 12:31:23'
# and timestamp < timestamp '2017-08-06 13:31:23'
#           Medication Reports\1039\2017-08\06\143006.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-06 14:00:06'
# and timestamp < timestamp '2017-08-06 15:00:06'
#           Medication Reports\1039\2017-08\06\185058.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-06 18:20:58'
# and timestamp < timestamp '2017-08-06 19:20:58'
#           Medication Reports\1039\2017-08\06\225633.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-06 22:26:33'
# and timestamp < timestamp '2017-08-06 23:26:33'
#           Medication Reports\1039\2017-08\07\022956.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-07 01:59:56'
# and timestamp < timestamp '2017-08-07 02:59:56'
#           Medication Reports\1039\2017-08\07\103627.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-07 10:06:27'
# and timestamp < timestamp '2017-08-07 11:06:27'
#           Medication Reports\1039\2017-08\07\132228.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-07 12:52:28'
# and timestamp < timestamp '2017-08-07 13:52:28'
#           Medication Reports\1039\2017-08\07\155228.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-07 15:22:28'
# and timestamp < timestamp '2017-08-07 16:22:28'
#           Medication Reports\1039\2017-08\07\230202.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-07 22:32:02'
# and timestamp < timestamp '2017-08-07 23:32:02'
#           Medication Reports\1039\2017-08\08\101335.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-08 09:43:35'
# and timestamp < timestamp '2017-08-08 10:43:35'
#           Medication Reports\1039\2017-08\08\151039.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-08 14:40:39'
# and timestamp < timestamp '2017-08-08 15:40:39'
#           Medication Reports\1039\2017-08\08\201446.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-08 19:44:46'
# and timestamp < timestamp '2017-08-08 20:44:46'
#           Medication Reports\1039\2017-08\09\004434.csv
# SELECT user_id-141583 AS SubjID, timestamp AS Timestamp, x AS X, y AS Y, z AS Z
# FROM watch_accelerometer
# where cohort != 'test'
# and user_id = 142622
# and timestamp >= timestamp '2017-08-09 00:14:34'
# and timestamp < timestamp '2017-08-09 01:14:34'
#           Medication Reports\1039\2017-08\09\104403.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9adb24d2773f> in <module>
#       1 # print the query for each report
# ----> 2 iterate_reports(timepoints_med, timepoints_symt, timepoints_diar)
#
# <ipython-input-9-1a762bef1655> in iterate_reports(timepoints_med, timepoints_symt, timepoints_diar)
#      12         if p[:81] == '//FS2.smpp.local\\\\RTO\\\\CIS-PD Study\\Patient Record Correlation\\Medication Reports':
#      13             S = p[82:86]
# ---> 14             S6 = str(user_id_4_to_6(S))
#      15         if p[:78] == '//FS2.smpp.local\\\\RTO\\\\CIS-PD Study\\Patient Record Correlation\\Symptom Reports':
#      16             S = p[79:83]
#
# <ipython-input-4-1f07af8733f5> in user_id_4_to_6(user_id_4)
#       4     # file contains a column for both 4-digit and 6-digit subject ID
#       5     for index, row in user_id_pairings.iterrows():
# ----> 6         if (int(row['SubjectCode']) == int(user_id_4)):
#       7
#       8             # return 'None' if the SubjectCode (4-digit) has no corresponding 6-digit ID (Subj ID Athena cell in csv is empty)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4350         # Things like `Series._get_value` (via .at) pass the EA directly here.
#    4351         s = getattr(series, '_values', series)
# -> 4352         if isinstance(s, (ExtensionArray, Index)) and is_scalar(key):
#    4353             # GH 20882, 21257
#    4354             # Unify Index and ExtensionArray treatment
#
# KeyboardInterrupt:
