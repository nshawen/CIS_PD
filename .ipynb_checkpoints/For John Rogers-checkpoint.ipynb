# %%
import os
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import xlsxwriter as xw
import pathlib

# %matplotlib inline

# %%
def process_activities(df):
# Helper function for process_annotations
# Sorts cycles after splitting raw annotations file into Day 1 and Day 2 data
#
# Inputs:  df - dataframe to sort annotations
#
# Outputs: df - processed dataframe
    complete = set(np.array(['Heart Rate Variability', 'MDS-UPDRS #1: Finger Tapping',
           'MDS-UPDRS #2: Hand Movements', 'MDS-UPDRS #3: Pronation-Supination',
           'MDS-UPDRS #4: Toe Tapping', 'MDS-UPDRS #5: Leg Agility',
           'MDS-UPDRS #6: Arising from Chair', 'MDS-UPDRS #7: Gait',
           'MDS-UPDRS #8: Postural Stability', 'MDS-UPDRS #9: Postural Hand Tremor',
           'MDS-UPDRS #10: Kinetic Hand Tremor', 'MDS-UPDRS #11: Rest Tremor',
           'Motor #1: Standing', 'Motor #2: Walking', 'Motor #3: Walking while Counting',
           'Motor #4: Finger to Nose', 'Motor #5: Alternating Hand Movements',
           'Motor #6: Sit to Stand', 'Motor #7: Drawing on Paper',
           'Motor #8: Typing on a Computer', 'Motor #9: Nuts and Bolts',
           'Motor #10: Drinking Water', 'Motor #11: Organizing Folder',
           'Motor #12: Folding Towels', 'Motor #13: Sitting']).flatten())

    sorter = set(df.EventType.unique().flatten())
    sorterIndex = dict(zip(sorter, range(len(sorter))))
    
    if (complete ^ sorter):
        print('Missing: ' + str(complete ^ sorter))
        
    df['EventType_Rank'] = df['EventType'].map(sorterIndex)
    df['Cycle'] = df.groupby('EventType')['Start Timestamp (ms)'].rank(ascending=True).astype(int)
    df[df['EventType'].str.contains('MDS-UPDRS')] = df[df['EventType'].str.contains('MDS-UPDRS')].replace(to_replace={'Cycle': {2: 3}})
    df[df['EventType'].str.contains('Heart')] = df[df['EventType'].str.contains('Heart')].replace(to_replace={'Cycle': {1: 'NaN', 2: 'NaN'}})
    df.sort_values(['EventType', 'EventType_Rank', 'Start Timestamp (ms)'], axis=0)
    
    return df


def process_annotations(path):
# Splits raw annotation file into Day 1 and Day 2 data by sheet in the .xlsx file
# 'RawAnnotations.xlsx'
#
# Inputs:  path - filepath of the subject folder containing annotations.csv
#
# Outputs: d1_df - dataframe containing all Day 1 activities and timestamps
#          d2_df - dataframe containing all Day 2 activities and timestamps
    df = pd.read_csv(os.path.join(path, 'annotations.csv'))
    del df['Timestamp (ms)']
    del df['AnnotationId']
    del df['AuthorId']
    
    df['Start Timestamp (ms)'] = pd.to_datetime(df['Start Timestamp (ms)'], unit='ms', utc=True).dt.tz_localize('UTC').dt.tz_convert('US/Central')
    df['Stop Timestamp (ms)'] = pd.to_datetime(df['Stop Timestamp (ms)'], unit='ms', utc=True).dt.tz_localize('UTC').dt.tz_convert('US/Central')
            
    testInfo = df[df.EventType == 'Testing Day'].dropna(how='any', axis=0)
    del testInfo['Stop Timestamp (ms)']
    del testInfo['EventType']
    del df['Value']
    
    testInfo = testInfo.rename(columns = {'Value':'Day', 'Start Timestamp (ms)':'Date'}).reset_index(drop=True)
    testInfo['Date'] = testInfo['Date'].dt.date
    
    df = df[(df.EventType != 'Testing Day')]

    Day1 = testInfo.loc[testInfo['Day'] == 'DAY 1', 'Date']
    Day2 = testInfo.loc[testInfo['Day'] == 'DAY 2', 'Date']

    d1_df = process_activities(df[df['Start Timestamp (ms)'].dt.date.isin(Day1)].reset_index(drop=True)).set_index('EventType')
    d2_df = process_activities(df[df['Start Timestamp (ms)'].dt.date.isin(Day2)].reset_index(drop=True)).set_index('EventType')

    file = os.path.join(path, 'RawAnnotations.xlsx')
    writer = pd.ExcelWriter(file, options={'remove_timezone': True})
    d1_df.to_excel(writer, sheet_name='Day 1')
    d2_df.to_excel(writer, sheet_name='Day 2')
    writer.save()
    
    return d1_df, d2_df

# %%
path = r'C:\Users\adai\Documents\PD Study Data\RawData\1020'

day1_df, day2_df = process_annotations(path)

print(day1_df)

accel = os.path.join(path, 'AccelData.xlsx')
gyro = os.path.join(path, 'GyroData.xlsx')
elec = os.path.join(path, 'ElecData.xlsx')

accel_writer = pd.ExcelWriter(accel, options={'remove_timezone': True})
gyro_writer = pd.ExcelWriter(gyro, options={'remove_timezone': True})
elec_writer = pd.ExcelWriter(elec, options={'remove_timezone': True})
temp = list()
for root, dirs, files in os.walk(path, topdown=True):
    for filenames in files:
        if filenames.endswith('accel.csv'):
            p = pathlib.Path(os.path.join(root, filenames))
            location = str(p.relative_to(path)).split("\\")[0]
            print(location)
# Out:
#                                                  Start Timestamp (ms)  \
# EventType
# Heart Rate Variability               2017-07-20 13:14:48.326000-05:00
# MDS-UPDRS #11: Rest Tremor           2017-07-20 13:36:55.425000-05:00
# MDS-UPDRS #9: Postural Hand Tremor   2017-07-20 13:37:17.851000-05:00
# MDS-UPDRS #10: Kinetic Hand Tremor   2017-07-20 13:37:25.201000-05:00
# MDS-UPDRS #1: Finger Tapping         2017-07-20 13:38:14.522000-05:00
# MDS-UPDRS #2: Hand Movements         2017-07-20 13:38:25.206000-05:00
# MDS-UPDRS #3: Pronation-Supination   2017-07-20 13:38:34.789000-05:00
# MDS-UPDRS #4: Toe Tapping            2017-07-20 13:38:42.755000-05:00
# MDS-UPDRS #5: Leg Agility            2017-07-20 13:38:51.011000-05:00
# MDS-UPDRS #6: Arising from Chair     2017-07-20 13:38:58.693000-05:00
# MDS-UPDRS #7: Gait                   2017-07-20 13:39:11.214000-05:00
# MDS-UPDRS #8: Postural Stability     2017-07-20 13:39:30.084000-05:00
# Motor #1: Standing                   2017-07-20 13:43:03.824000-05:00
# Motor #2: Walking                    2017-07-20 13:43:45.337000-05:00
# Motor #3: Walking while Counting     2017-07-20 13:44:31.031000-05:00
# Motor #4: Finger to Nose             2017-07-20 13:45:32.123000-05:00
# Motor #5: Alternating Hand Movements 2017-07-20 13:46:14.029000-05:00
# Motor #6: Sit to Stand               2017-07-20 13:46:56.311000-05:00
# Motor #7: Drawing on Paper           2017-07-20 13:47:31.690000-05:00
# Motor #8: Typing on a Computer       2017-07-20 13:48:27.102000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 13:49:15.462000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 13:49:15.462000-05:00
# Motor #10: Drinking Water            2017-07-20 13:50:08.134000-05:00
# Motor #11: Organizing Folder         2017-07-20 13:51:13.685000-05:00
# Motor #12: Folding Towels            2017-07-20 13:52:11.335000-05:00
# Motor #13: Sitting                   2017-07-20 13:52:51.497000-05:00
# Motor #1: Standing                   2017-07-20 14:55:39.583000-05:00
# Motor #2: Walking                    2017-07-20 14:56:20.305000-05:00
# Motor #3: Walking while Counting     2017-07-20 14:56:58.017000-05:00
# Motor #4: Finger to Nose             2017-07-20 14:57:42.741000-05:00
# ...                                                               ...
# Motor #8: Typing on a Computer       2017-07-20 15:49:55.901000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 15:50:43.711000-05:00
# Motor #10: Drinking Water            2017-07-20 15:51:31.685000-05:00
# Motor #11: Organizing Folder         2017-07-20 15:52:13.864000-05:00
# Motor #12: Folding Towels            2017-07-20 15:52:58.205000-05:00
# Motor #13: Sitting                   2017-07-20 15:53:31.578000-05:00
# Motor #1: Standing                   2017-07-20 16:18:11.722000-05:00
# Motor #2: Walking                    2017-07-20 16:18:51.162000-05:00
# Motor #3: Walking while Counting     2017-07-20 16:19:32.136000-05:00
# Motor #4: Finger to Nose             2017-07-20 16:20:21.292000-05:00
# Motor #5: Alternating Hand Movements 2017-07-20 16:21:12.258000-05:00
# Motor #6: Sit to Stand               2017-07-20 16:21:44.428000-05:00
# MDS-UPDRS #1: Finger Tapping         2017-07-20 16:24:16.207000-05:00
# MDS-UPDRS #2: Hand Movements         2017-07-20 16:24:30.578000-05:00
# MDS-UPDRS #3: Pronation-Supination   2017-07-20 16:24:45.808000-05:00
# MDS-UPDRS #4: Toe Tapping            2017-07-20 16:24:57.505000-05:00
# MDS-UPDRS #5: Leg Agility            2017-07-20 16:25:11.790000-05:00
# MDS-UPDRS #6: Arising from Chair     2017-07-20 16:25:22.731000-05:00
# MDS-UPDRS #7: Gait                   2017-07-20 16:25:43.975000-05:00
# MDS-UPDRS #8: Postural Stability     2017-07-20 16:26:00.439000-05:00
# MDS-UPDRS #9: Postural Hand Tremor   2017-07-20 16:26:25.763000-05:00
# MDS-UPDRS #10: Kinetic Hand Tremor   2017-07-20 16:26:32.495000-05:00
# Motor #7: Drawing on Paper           2017-07-20 16:28:06.346000-05:00
# Motor #8: Typing on a Computer       2017-07-20 16:28:56.696000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 16:30:10.299000-05:00
# Motor #10: Drinking Water            2017-07-20 16:30:55.822000-05:00
# Motor #11: Organizing Folder         2017-07-20 16:31:34.404000-05:00
# Motor #12: Folding Towels            2017-07-20 16:32:16.804000-05:00
# Motor #13: Sitting                   2017-07-20 16:32:50.581000-05:00
# Heart Rate Variability               2017-07-20 16:34:05.939000-05:00
#
#                                                   Stop Timestamp (ms)  \
# EventType
# Heart Rate Variability               2017-07-20 13:20:48.328000-05:00
# MDS-UPDRS #11: Rest Tremor           2017-07-20 13:37:11.066000-05:00
# MDS-UPDRS #9: Postural Hand Tremor   2017-07-20 13:37:22.796000-05:00
# MDS-UPDRS #10: Kinetic Hand Tremor   2017-07-20 13:37:30.709000-05:00
# MDS-UPDRS #1: Finger Tapping         2017-07-20 13:38:22.444000-05:00
# MDS-UPDRS #2: Hand Movements         2017-07-20 13:38:32.651000-05:00
# MDS-UPDRS #3: Pronation-Supination   2017-07-20 13:38:39.707000-05:00
# MDS-UPDRS #4: Toe Tapping            2017-07-20 13:38:48.707000-05:00
# MDS-UPDRS #5: Leg Agility            2017-07-20 13:38:56.588000-05:00
# MDS-UPDRS #6: Arising from Chair     2017-07-20 13:39:02.972000-05:00
# MDS-UPDRS #7: Gait                   2017-07-20 13:39:24.920000-05:00
# MDS-UPDRS #8: Postural Stability     2017-07-20 13:39:38.540000-05:00
# Motor #1: Standing                   2017-07-20 13:43:36.981000-05:00
# Motor #2: Walking                    2017-07-20 13:44:19.345000-05:00
# Motor #3: Walking while Counting     2017-07-20 13:45:05.927000-05:00
# Motor #4: Finger to Nose             2017-07-20 13:46:11.278000-05:00
# Motor #5: Alternating Hand Movements 2017-07-20 13:46:51.362000-05:00
# Motor #6: Sit to Stand               2017-07-20 13:47:13.118000-05:00
# Motor #7: Drawing on Paper           2017-07-20 13:48:06.825000-05:00
# Motor #8: Typing on a Computer       2017-07-20 13:49:04.179000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 13:49:49.568000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 13:49:49.568000-05:00
# Motor #10: Drinking Water            2017-07-20 13:50:43.130000-05:00
# Motor #11: Organizing Folder         2017-07-20 13:51:51.999000-05:00
# Motor #12: Folding Towels            2017-07-20 13:52:43.317000-05:00
# Motor #13: Sitting                   2017-07-20 13:53:25.924000-05:00
# Motor #1: Standing                   2017-07-20 14:56:14.034000-05:00
# Motor #2: Walking                    2017-07-20 14:56:53.357000-05:00
# Motor #3: Walking while Counting     2017-07-20 14:57:31.172000-05:00
# Motor #4: Finger to Nose             2017-07-20 14:58:22.972000-05:00
# ...                                                               ...
# Motor #8: Typing on a Computer       2017-07-20 15:50:33.919000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 15:51:25.801000-05:00
# Motor #10: Drinking Water            2017-07-20 15:52:00.732000-05:00
# Motor #11: Organizing Folder         2017-07-20 15:52:53.377000-05:00
# Motor #12: Folding Towels            2017-07-20 15:53:28.693000-05:00
# Motor #13: Sitting                   2017-07-20 15:54:04.426000-05:00
# Motor #1: Standing                   2017-07-20 16:18:45.526000-05:00
# Motor #2: Walking                    2017-07-20 16:19:26.461000-05:00
# Motor #3: Walking while Counting     2017-07-20 16:20:05.926000-05:00
# Motor #4: Finger to Nose             2017-07-20 16:21:02.259000-05:00
# Motor #5: Alternating Hand Movements 2017-07-20 16:21:41.908000-05:00
# Motor #6: Sit to Stand               2017-07-20 16:22:01.251000-05:00
# MDS-UPDRS #1: Finger Tapping         2017-07-20 16:24:27.041000-05:00
# MDS-UPDRS #2: Hand Movements         2017-07-20 16:24:43.485000-05:00
# MDS-UPDRS #3: Pronation-Supination   2017-07-20 16:24:53.420000-05:00
# MDS-UPDRS #4: Toe Tapping            2017-07-20 16:25:07.586000-05:00
# MDS-UPDRS #5: Leg Agility            2017-07-20 16:25:19.877000-05:00
# MDS-UPDRS #6: Arising from Chair     2017-07-20 16:25:30.447000-05:00
# MDS-UPDRS #7: Gait                   2017-07-20 16:25:56.413000-05:00
# MDS-UPDRS #8: Postural Stability     2017-07-20 16:26:04.951000-05:00
# MDS-UPDRS #9: Postural Hand Tremor   2017-07-20 16:26:29.215000-05:00
# MDS-UPDRS #10: Kinetic Hand Tremor   2017-07-20 16:26:35.432000-05:00
# Motor #7: Drawing on Paper           2017-07-20 16:28:42.558000-05:00
# Motor #8: Typing on a Computer       2017-07-20 16:29:32.643000-05:00
# Motor #9: Nuts and Bolts             2017-07-20 16:30:48.263000-05:00
# Motor #10: Drinking Water            2017-07-20 16:31:20.147000-05:00
# Motor #11: Organizing Folder         2017-07-20 16:32:13.674000-05:00
# Motor #12: Folding Towels            2017-07-20 16:32:45.386000-05:00
# Motor #13: Sitting                   2017-07-20 16:33:27.035000-05:00
# Heart Rate Variability               2017-07-20 16:40:05.945000-05:00
#
#                                       EventType_Rank Cycle
# EventType
# Heart Rate Variability                             7   NaN
# MDS-UPDRS #11: Rest Tremor                        11     1
# MDS-UPDRS #9: Postural Hand Tremor                17     1
# MDS-UPDRS #10: Kinetic Hand Tremor                 0     1
# MDS-UPDRS #1: Finger Tapping                       2     1
# MDS-UPDRS #2: Hand Movements                       3     1
# MDS-UPDRS #3: Pronation-Supination                22     1
# MDS-UPDRS #4: Toe Tapping                          4     1
# MDS-UPDRS #5: Leg Agility                          9     1
# MDS-UPDRS #6: Arising from Chair                   6     1
# MDS-UPDRS #7: Gait                                21     1
# MDS-UPDRS #8: Postural Stability                  18     1
# Motor #1: Standing                                16     1
# Motor #2: Walking                                  8     1
# Motor #3: Walking while Counting                   5     1
# Motor #4: Finger to Nose                          14     1
# Motor #5: Alternating Hand Movements              19     1
# Motor #6: Sit to Stand                            10     1
# Motor #7: Drawing on Paper                        15     1
# Motor #8: Typing on a Computer                    12     1
# Motor #9: Nuts and Bolts                           1     1
# Motor #9: Nuts and Bolts                           1     1
# Motor #10: Drinking Water                         13     1
# Motor #11: Organizing Folder                      24     1
# Motor #12: Folding Towels                         20     1
# Motor #13: Sitting                                23     1
# Motor #1: Standing                                16     2
# Motor #2: Walking                                  8     2
# Motor #3: Walking while Counting                   5     2
# Motor #4: Finger to Nose                          14     2
# ...                                              ...   ...
# Motor #8: Typing on a Computer                    12     4
# Motor #9: Nuts and Bolts                           1     5
# Motor #10: Drinking Water                         13     4
# Motor #11: Organizing Folder                      24     4
# Motor #12: Folding Towels                         20     4
# Motor #13: Sitting                                23     4
# Motor #1: Standing                                16     5
# Motor #2: Walking                                  8     5
# Motor #3: Walking while Counting                   5     5
# Motor #4: Finger to Nose                          14     5
# Motor #5: Alternating Hand Movements              19     5
# Motor #6: Sit to Stand                            10     5
# MDS-UPDRS #1: Finger Tapping                       2     3
# MDS-UPDRS #2: Hand Movements                       3     3
# MDS-UPDRS #3: Pronation-Supination                22     3
# MDS-UPDRS #4: Toe Tapping                          4     3
# MDS-UPDRS #5: Leg Agility                          9     3
# MDS-UPDRS #6: Arising from Chair                   6     3
# MDS-UPDRS #7: Gait                                21     3
# MDS-UPDRS #8: Postural Stability                  18     3
# MDS-UPDRS #9: Postural Hand Tremor                17     3
# MDS-UPDRS #10: Kinetic Hand Tremor                 0     3
# Motor #7: Drawing on Paper                        15     5
# Motor #8: Typing on a Computer                    12     5
# Motor #9: Nuts and Bolts                           1     6
# Motor #10: Drinking Water                         13     5
# Motor #11: Organizing Folder                      24     5
# Motor #12: Folding Towels                         20     5
# Motor #13: Sitting                                23     5
# Heart Rate Variability                             7   NaN
#
# [89 rows x 4 columns]
# accel.csv
# anterior_thigh_left
# accel.csv
# anterior_thigh_left
# accel.csv
# anterior_thigh_right
# accel.csv
# anterior_thigh_right
# accel.csv
# distal_lateral_shank_left
# accel.csv
# distal_lateral_shank_left
# accel.csv
# distal_lateral_shank_right
# accel.csv
# distal_lateral_shank_right
# accel.csv
# dorsal_hand_left
# accel.csv
# dorsal_hand_left
# accel.csv
# dorsal_hand_right
# accel.csv
# dorsal_hand_right
# accel.csv
# flexor_digitorum_left
# accel.csv
# flexor_digitorum_left
# accel.csv
# flexor_digitorum_right
# accel.csv
# flexor_digitorum_right
# accel.csv
# medial_chest
# accel.csv
# medial_chest
# accel.csv
# sacrum
# accel.csv
# sacrum
