# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %matplotlib inline

# %%
path = r'C:\Users\adai\Documents\PD Study Data\Subjects\1004'
path2 = r'C:\Users\adai\Documents\PD Study Data\Subjects'

for folders in os.listdir(path2):
    print(folders)

for root, dirs, files in os.walk(path):
    for filenames in files:
        #if os.path.splittext(filenames)[-1] == '.csv':
        if filenames.endswith('annotations.csv'):
            filename_path = os.path.join(root, filenames)
            print(filenames)
            print(filename_path)
        elif filenames.endswith('gyro.csv'):
            filename_path = os.path.join(root, filenames)
            print(filenames)
            print(filename_path)
        elif filenames.endswith('accel.csv'):
            filename_path = os.path.join(root, filenames)
            print(filenames)
            print(filename_path)
        elif filenames.endswith('elec.csv'):
            filename_path = os.path.join(root, filenames)
            print(filenames)
            print(filename_path)
# Out:
# .DS_Store
# 1004
# 1016
# 1018
# annotations.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\annotations.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yeg\2017-07-07T13-13-06-641Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yeg\2017-07-07T13-13-06-641Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yeg\2017-07-07T14-20-06-069Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yeg\2017-07-07T14-20-06-069Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yeg\2017-07-07T14-41-03-004Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yeg\2017-07-07T14-41-03-004Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yfe\2017-07-18T13-16-29-474Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_left\d5la7yfe\2017-07-18T13-16-29-474Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7y58\2017-07-07T13-13-02-523Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7y58\2017-07-07T13-13-02-523Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7y58\2017-07-07T14-19-59-498Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7y58\2017-07-07T14-19-59-498Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7y58\2017-07-07T14-40-36-193Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7y58\2017-07-07T14-40-36-193Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7ybu\2017-07-18T13-16-23-143Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\anterior_thigh_right\d5la7ybu\2017-07-18T13-16-23-143Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_left\d5la7y58\2017-07-18T13-17-43-137Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_left\d5la7y58\2017-07-18T13-17-43-137Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_left\d5la7y9p\2017-07-07T13-15-07-749Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_left\d5la7y9p\2017-07-07T13-15-07-749Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_left\d5la7y9p\2017-07-07T14-20-30-233Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_left\d5la7y9p\2017-07-07T14-20-30-233Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_right\d5la7yer\2017-07-18T13-17-34-937Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_right\d5la7yer\2017-07-18T13-17-34-937Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_right\d5la7yfe\2017-07-07T13-15-01-828Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_right\d5la7yfe\2017-07-07T13-15-01-828Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_right\d5la7yfe\2017-07-07T14-20-27-336Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\distal_lateral_shank_right\d5la7yfe\2017-07-07T14-20-27-336Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_left\d5la7yeg\2017-07-18T13-18-38-833Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_left\d5la7yeg\2017-07-18T13-18-38-833Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_left\d5la7yer\2017-07-07T13-15-20-699Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_left\d5la7yer\2017-07-07T13-15-20-699Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_left\d5la7yer\2017-07-07T14-20-53-372Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_left\d5la7yer\2017-07-07T14-20-53-372Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_right\d5la7ybu\2017-07-07T13-15-16-759Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_right\d5la7ybu\2017-07-07T13-15-16-759Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_right\d5la7ybu\2017-07-07T14-20-44-065Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_right\d5la7ybu\2017-07-07T14-20-44-065Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_right\d5la7ycl\2017-07-18T13-17-50-669Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\dorsal_hand_right\d5la7ycl\2017-07-18T13-17-50-669Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7y9p\2017-07-18T13-16-40-019Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7y9p\2017-07-18T13-16-40-019Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7yf3\2017-07-07T13-13-56-638Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7yf3\2017-07-07T13-13-56-638Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7yf3\2017-07-07T14-20-13-446Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7yf3\2017-07-07T14-20-13-446Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7yf3\2017-07-07T14-41-22-432Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_left\d5la7yf3\2017-07-07T14-41-22-432Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7y9m\2017-07-07T13-13-16-692Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7y9m\2017-07-07T13-13-16-692Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7y9m\2017-07-07T14-20-09-787Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7y9m\2017-07-07T14-20-09-787Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7y9m\2017-07-07T14-41-15-709Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7y9m\2017-07-07T14-41-15-709Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7yf3\2017-07-18T13-16-33-327Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\flexor_digitorum_right\d5la7yf3\2017-07-18T13-16-33-327Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\medial_chest\d5la7ybi\2017-07-07T13-14-11-614Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\medial_chest\d5la7ybi\2017-07-07T13-14-11-614Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\medial_chest\d5la7ybi\2017-07-07T14-20-18-392Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\medial_chest\d5la7ybi\2017-07-07T14-20-18-392Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\medial_chest\d5la7ybi\2017-07-18T13-16-15-384Z\accel.csv
# elec.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\medial_chest\d5la7ybi\2017-07-18T13-16-15-384Z\elec.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\sacrum\d5la7y9m\2017-07-18T13-17-27-043Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\sacrum\d5la7y9m\2017-07-18T13-17-27-043Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\sacrum\d5la7ycl\2017-07-07T13-14-55-383Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\sacrum\d5la7ycl\2017-07-07T13-14-55-383Z\gyro.csv
# accel.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\sacrum\d5la7ycl\2017-07-07T14-20-22-735Z\accel.csv
# gyro.csv
# C:\Users\adai\Documents\PD Study Data\Subjects\1004\sacrum\d5la7ycl\2017-07-07T14-20-22-735Z\gyro.csv

# %%
path = r'C:\Users\adai\Documents\PD Study Data\Subjects\1004'

for root, dirs, files in os.walk(path):
    for filenames in files:
        #if os.path.splittext(filenames)[-1] == '.csv':
        if filenames.endswith('.csv'):
            filename_path = os.path.join(root, filenames)
            print(filenames)
            print(filename_path)

#files = os.listdir(path)

#for entries in files:
#    if entries == 'annotations.csv':
#        print(os.path.join(path, entries))
#        df = pd.read_csv(os.path.join(path, entries))

        
### Annotations Processing
# removes unnecessary data columns
del df['Timestamp (ms)']
del df['AnnotationId']
del df['AuthorId']

df['Start Timestamp (ms)'] = pd.to_datetime(df['Start Timestamp (ms)'], unit='ms', utc=True).dt.tz_localize('UTC').dt.tz_convert('US/Central')
df['Stop Timestamp (ms)'] = pd.to_datetime(df['Stop Timestamp (ms)'], unit='ms', utc=True).dt.tz_localize('UTC').dt.tz_convert('US/Central')

testDay = df[df.EventType == 'Testing Day'].dropna(how='any').iloc[0]['Value'].replace(" ", "")

df = df[(df.EventType != 'Testing Day')]
del df['Value']

### Activity Sorting
sorter = df.EventType.unique()
sorterIndex = dict(zip(sorter,range(len(sorter))))

print(sorter)

df['EventType_Rank'] = df['EventType'].map(sorterIndex)
df['Cycle'] = df.groupby('EventType')['Start Timestamp (ms)'].rank(ascending=True).astype(int)
df[df['EventType'].str.contains('MDS-UPDRS')] = df[df['EventType'].str.contains('MDS-UPDRS')].replace(to_replace={'Cycle': {2: 3}})
df[df['EventType'].str.contains('Heart')] = df[df['EventType'].str.contains('Heart')].replace(to_replace={'Cycle': {1: 'NaN', 2: 'NaN'}})
df.sort_values(['EventType', 'EventType_Rank', 'Start Timestamp (ms)'], axis=0)

name = 'NewAnnotations_' + str(testDay) + '.xlsx'
writer = pd.ExcelWriter(name, options={'remove_timezone': True})
df.to_excel(writer,'Sheet1')

# %%
def activityCheck(activities):
# Checks the downloaded data from mc10cloud.com for missing or duplicate
# activity timestamps and returns missing and duplicate activity labels
#
# Inputs: activities - list of unique activities in the entire dataframe per day
#         testDay - desired testDay to scan
#
# Outputs: missing - list of missing activities per test day and cycle
#          duplicates - list of duplicate activity labels per test day and cycle
complete = {'Heart Rate Variability', 'MDS-UPDRS #1: Finger Tapping',
           'MDS-UPDRS #2: Hand Movements', 'MDS-UPDRS #3: Pronation-Supination',
           'MDS-UPDRS #4: Toe Tapping', 'MDS-UPDRS #5: Leg Agility',
           'MDS-UPDRS #6: Arising from Chair', 'MDS-UPDRS #7: Gait',
           'MDS-UPDRS #8: Postural Stability', 'MDS-UPDRS #9: Postural Hand Tremor',
           'MDS-UPDRS #10: Kinetic Hand Tremor', 'MDS-UPDRS #11: Rest Tremor',
           'Motor #1: Standing', 'Motor #2: Walking', 'Motor #3: Walking while Counting',
           'Motor #4: Finger to Nose', 'Motor #5: Alternating Hand Movements',
           'Motor #6: Sit to Stand', 'Motor #7: Drawing on Paper',
           'Motor #8: Typing on a Computer', 'Motor #9: Nuts and Bolts',
           'Motor #10: Drinking Water', 'Motor #11: Organizing Folder',
           'Motor #12: Folding Towels', 'Motor #13: Sitting', 'Testing Day'}

# %%
def merge_timestamps(df, duplicates):
# Inputs:  df - original annotation dataframe
#          duplicates - dataframe of activities to merge
#
# Outputs: df_new - updated dataframe with merged timestampes per activities
    for labels in duplicates:

# %%
def missing_timestamps(df, missing):
# Inputs:  df - original annotation dataframe
#          missing - dataframe of missing activity labels
#
# Outputs: df_new - updated dataframe with placeholder activities to indicate
#                   the activity was missing
    for labels in missing:

# %%
def split_timestamps(df, split):
# Inputs:  df - original annotation dataframe
#          split - dataframe of activity labels needed to be split
#
# Outputs: df_new - updated dataframe with split activities
    for labels in split:
