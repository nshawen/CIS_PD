# %%
import os
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import xlsxwriter as xw
import pathlib

# %matplotlib inline

# %%
def process_activities(df):
# Helper function for process_annotations
# Sorts cycles after splitting raw annotations file into Day 1 and Day 2 data
#
# Inputs:  df - dataframe to sort annotations
#
# Outputs: df - processed dataframe
    """complete = set(np.array(['Heart Rate Variability', 'MDS-UPDRS #1: Finger Tapping',
           'MDS-UPDRS #2: Hand Movements', 'MDS-UPDRS #3: Pronation-Supination',
           'MDS-UPDRS #4: Toe Tapping', 'MDS-UPDRS #5: Leg Agility',
           'MDS-UPDRS #6: Arising from Chair', 'MDS-UPDRS #7: Gait',
           'MDS-UPDRS #8: Postural Stability', 'MDS-UPDRS #9: Postural Hand Tremor',
           'MDS-UPDRS #10: Kinetic Hand Tremor', 'MDS-UPDRS #11: Rest Tremor',
           'Motor #1: Standing', 'Motor #2: Walking', 'Motor #3: Walking while Counting',
           'Motor #4: Finger to Nose', 'Motor #5: Alternating Hand Movements',
           'Motor #6: Sit to Stand', 'Motor #7: Drawing on Paper',
           'Motor #8: Typing on a Computer', 'Motor #9: Nuts and Bolts',
           'Motor #10: Drinking Water', 'Motor #11: Organizing Folder',
           'Motor #12: Folding Towels', 'Motor #13: Sitting']).flatten())"""

    sorter = set(df.EventType.unique().flatten())
    sorterIndex = dict(zip(sorter, range(len(sorter))))
    
    """if (complete ^ sorter):
        print('Missing: ' + str(complete ^ sorter))"""
        
    df['EventType_Rank'] = df['EventType'].map(sorterIndex)
    df['Cycle'] = df.groupby('EventType')['Start Timestamp (ms)'].rank(ascending=True).astype(int)
    df[df['EventType'].str.contains('MDS-UPDRS')] = df[df['EventType'].str.contains('MDS-UPDRS')].replace(to_replace={'Cycle': {2: 3}})
    df[df['EventType'].str.contains('Heart')] = df[df['EventType'].str.contains('Heart')].replace(to_replace={'Cycle': {1: 'NaN', 2: 'NaN'}})
    df.sort_values(['EventType', 'EventType_Rank', 'Start Timestamp (ms)'], axis=0)
    
    return df


def process_annotations(path):
# Splits raw annotation file into Day 1 and Day 2 data by sheet in the .xlsx file
# 'RawAnnotations.xlsx'
#
# Inputs:  path - filepath of the subject folder containing annotations.csv
#
# Outputs: d1_df - dataframe containing all Day 1 activities and timestamps
#          d2_df - dataframe containing all Day 2 activities and timestamps
    df = pd.read_csv(os.path.join(path, 'annotations.csv'))
    del df['Timestamp (ms)']
    del df['AnnotationId']
    del df['AuthorId']
    
    df['Start Timestamp (ms)'] = pd.to_datetime(df['Start Timestamp (ms)'], unit='ms', utc=True).dt.tz_localize('UTC').dt.tz_convert('US/Central')
    df['Stop Timestamp (ms)'] = pd.to_datetime(df['Stop Timestamp (ms)'], unit='ms', utc=True).dt.tz_localize('UTC').dt.tz_convert('US/Central')
            
    testInfo = df[df.EventType == 'Testing Day'].dropna(how='any', axis=0)
    del testInfo['Stop Timestamp (ms)']
    del testInfo['EventType']
    del df['Value']
    
    testInfo = testInfo.rename(columns = {'Value':'Day', 'Start Timestamp (ms)':'Date'}).reset_index(drop=True)
    testInfo['Date'] = testInfo['Date'].dt.date
    
    df = df[(df.EventType != 'Testing Day')]

    Day1 = testInfo.loc[testInfo['Day'] == 'DAY 1', 'Date']
    Day2 = testInfo.loc[testInfo['Day'] == 'DAY 2', 'Date']

    d1_df = process_activities(df[df['Start Timestamp (ms)'].dt.date.isin(Day1)].reset_index(drop=True)).set_index('EventType')
    d2_df = process_activities(df[df['Start Timestamp (ms)'].dt.date.isin(Day2)].reset_index(drop=True)).set_index('EventType')
    total_df = process_activities(df.reset_index(drop=True))
    
    file = os.path.join(path, 'RawAnnotations.xlsx')
    writer = pd.ExcelWriter(file, options={'remove_timezone': True})
    d1_df.to_excel(writer, sheet_name='Day 1')
    d2_df.to_excel(writer, sheet_name='Day 2')
    writer.save()
    
    return d1_df, d2_df, total_df

# %%
"""error = pd.read_excel(path_error, sheetname='Errors')
error = error[error['Participant'] == 1004].set_index('Participant')

if not error[error['Error'] == 'Split'].empty:
    split = error[error['Error'] == 'Split']
    print(split)
    if (split.loc[split['Error'] == 'Split', 'Day'] == 'Day 1').bool:
        print('Day 1')
    else:
        print('Day 2')
elif not error[error['Error'] == 'Merge'].empty:
    
elif not error[error['Error'] == 'Absent'].empty:
    
else:
"""

complete = list(['Heart Rate Variability', 'MDS-UPDRS #1: Finger Tapping',
           'MDS-UPDRS #2: Hand Movements', 'MDS-UPDRS #3: Pronation-Supination',
           'MDS-UPDRS #4: Toe Tapping', 'MDS-UPDRS #5: Leg Agility',
           'MDS-UPDRS #6: Arising from Chair', 'MDS-UPDRS #7: Gait',
           'MDS-UPDRS #8: Postural Stability', 'MDS-UPDRS #9: Postural Hand Tremor',
           'MDS-UPDRS #10: Kinetic Hand Tremor', 'MDS-UPDRS #11: Rest Tremor',
           'Motor #1: Standing', 'Motor #2: Walking', 'Motor #3: Walking while Counting',
           'Motor #4: Finger to Nose', 'Motor #5: Alternating Hand Movements',
           'Motor #6: Sit to Stand', 'Motor #7: Drawing on Paper',
           'Motor #8: Typing on a Computer', 'Motor #9: Nuts and Bolts',
           'Motor #10: Drinking Water', 'Motor #11: Organizing Folder',
           'Motor #12: Folding Towels', 'Motor #13: Sitting'])

path = r'C:\Users\adai\Documents\PD Study Data\RawData\1004'

day1_df, day2_df, total_df = process_annotations(path)

accel_writer = pd.ExcelWriter(os.path.join(path, 'AccelData.xlsx'), options={'remove_timezone': True})
gyro_writer = pd.ExcelWriter(os.path.join(path, 'GyroData.xlsx'), options={'remove_timezone': True})
elec_writer = pd.ExcelWriter(os.path.join(path, 'ElecData.xlsx'), options={'remove_timezone': True})

locations = [locs for locs in os.listdir(path) if os.path.isdir(os.path.join(path, locs))]

accel = {locs: pd.DataFrame() for locs in locations}
gyro = {locs: pd.DataFrame() for locs in locations}
elec = {locs: pd.DataFrame() for locs in locations}

"""for root, dirs, files in os.walk(path, topdown=True):
    for filenames in files:
        if filenames.endswith('accel.csv'):
            p = pathlib.Path(os.path.join(root, filenames))
            location = str(p.relative_to(path)).split("\\")[0]
            temp_df = pd.read_csv(p)
            accel[location] = accel[location].append(temp_df)
            
        elif filenames.endswith('gyro.csv'):
            p = pathlib.Path(os.path.join(root, filenames))
            location = str(p.relative_to(path)).split("\\")[0]
            temp_df = pd.read_csv(p)
            gyro[location] = gyro[location].append(temp_df)
            
        if filenames.endswith('elec.csv'):
            p = pathlib.Path(os.path.join(root, filenames))
            location = str(p.relative_to(path)).split("\\")[0]
            temp_df = pd.read_csv(p)
            elec[location] = elec[location].append(temp_df)"""

loc_dict = {locs: pd.DataFrame() for locs in complete}
act_dict = {acts: pd.DataFrame() for acts in complete}

for activities in complete:
    loc_dict[activities] = pd.DataFrame({'Sensor:': locations})
    print(activities)
    print(loc_dict[activities])
    temp_df = total_df[total_df['EventType'] == activities].reset_index(drop=True)
    print(temp_df)
# Out:
# Heart Rate Variability
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                 EventType             Start Timestamp (ms)  \
# 0  Heart Rate Variability 2017-07-07 08:15:33.880000-05:00
# 1  Heart Rate Variability 2017-07-07 11:35:53.043000-05:00
# 2  Heart Rate Variability 2017-07-18 08:18:52.238000-05:00
# 3  Heart Rate Variability 2017-07-18 09:03:38.709000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:21:33.890000-05:00               1   NaN
# 1 2017-07-07 11:41:53.054000-05:00               1   NaN
# 2 2017-07-18 08:24:52.244000-05:00               1     3
# 3 2017-07-18 09:09:38.713000-05:00               1     4
# 4
# MDS-UPDRS #1: Finger Tapping
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                       EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #1: Finger Tapping 2017-07-07 08:32:44.865000-05:00
# 1  MDS-UPDRS #1: Finger Tapping 2017-07-07 10:00:07.797000-05:00
# 2  MDS-UPDRS #1: Finger Tapping 2017-07-18 08:32:48.705000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:32:56.490000-05:00              24     1
# 1 2017-07-07 10:00:19.664000-05:00              24     3
# 2 2017-07-18 08:32:54.679000-05:00              24     3
# 3
# MDS-UPDRS #2: Hand Movements
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                       EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #2: Hand Movements 2017-07-07 08:33:01.669000-05:00
# 1  MDS-UPDRS #2: Hand Movements 2017-07-07 10:00:25.635000-05:00
# 2  MDS-UPDRS #2: Hand Movements 2017-07-18 08:32:58.139000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:33:11.035000-05:00              15     1
# 1 2017-07-07 10:00:34.817000-05:00              15     3
# 2 2017-07-18 08:33:04.802000-05:00              15     3
# 3
# MDS-UPDRS #3: Pronation-Supination
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                             EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #3: Pronation-Supination 2017-07-07 08:33:15.837000-05:00
# 1  MDS-UPDRS #3: Pronation-Supination 2017-07-07 10:00:42.179000-05:00
# 2  MDS-UPDRS #3: Pronation-Supination 2017-07-18 08:33:09.814000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:33:23.196000-05:00              10     1
# 1 2017-07-07 10:00:50.002000-05:00              10     3
# 2 2017-07-18 08:33:14.885000-05:00              10     3
# 3
# MDS-UPDRS #4: Toe Tapping
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                    EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #4: Toe Tapping 2017-07-07 08:33:28.186000-05:00
# 1  MDS-UPDRS #4: Toe Tapping 2017-07-07 10:00:55.130000-05:00
# 2  MDS-UPDRS #4: Toe Tapping 2017-07-18 08:33:18.902000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:33:39.320000-05:00               4     1
# 1 2017-07-07 10:01:05.252000-05:00               4     3
# 2 2017-07-18 08:33:29.336000-05:00               4     3
# 3
# MDS-UPDRS #5: Leg Agility
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                    EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #5: Leg Agility 2017-07-07 08:33:43.006000-05:00
# 1  MDS-UPDRS #5: Leg Agility 2017-07-07 10:01:08.793000-05:00
# 2  MDS-UPDRS #5: Leg Agility 2017-07-18 08:33:33.012000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:33:50.233000-05:00               7     1
# 1 2017-07-07 10:01:16.634000-05:00               7     3
# 2 2017-07-18 08:33:39.335000-05:00               7     3
# 3
# MDS-UPDRS #6: Arising from Chair
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                           EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #6: Arising from Chair 2017-07-07 08:33:53.974000-05:00
# 1  MDS-UPDRS #6: Arising from Chair 2017-07-07 10:01:20.254000-05:00
# 2  MDS-UPDRS #6: Arising from Chair 2017-07-18 08:33:42.950000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:34:00.149000-05:00              13     1
# 1 2017-07-07 10:01:24.915000-05:00              13     3
# 2 2017-07-18 08:33:48.351000-05:00              13     3
# 3
# MDS-UPDRS #7: Gait
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#             EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #7: Gait 2017-07-07 08:34:05.293000-05:00
# 1  MDS-UPDRS #7: Gait 2017-07-07 10:01:29.446000-05:00
# 2  MDS-UPDRS #7: Gait 2017-07-18 08:33:53.567000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:34:18.738000-05:00              17     1
# 1 2017-07-07 10:01:37.947000-05:00              17     3
# 2 2017-07-18 08:34:01.802000-05:00              17     3
# 3
# MDS-UPDRS #8: Postural Stability
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                           EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #8: Postural Stability 2017-07-07 08:34:29.293000-05:00
# 1  MDS-UPDRS #8: Postural Stability 2017-07-07 10:01:40.797000-05:00
# 2  MDS-UPDRS #8: Postural Stability 2017-07-18 08:34:05.648000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:34:37.034000-05:00               3     1
# 1 2017-07-07 10:01:48.153000-05:00               3     3
# 2 2017-07-18 08:34:10.516000-05:00               3     3
# 3
# MDS-UPDRS #9: Postural Hand Tremor
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                             EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #9: Postural Hand Tremor 2017-07-07 08:35:05.427000-05:00
# 1  MDS-UPDRS #9: Postural Hand Tremor 2017-07-07 10:02:02.910000-05:00
# 2  MDS-UPDRS #9: Postural Hand Tremor 2017-07-18 08:34:32.602000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:35:15.713000-05:00              22     1
# 1 2017-07-07 10:02:09.431000-05:00              22     3
# 2 2017-07-18 08:34:37.251000-05:00              22     3
# 3
# MDS-UPDRS #10: Kinetic Hand Tremor
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                             EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #10: Kinetic Hand Tremor 2017-07-07 10:02:16.987000-05:00
# 1  MDS-UPDRS #10: Kinetic Hand Tremor 2017-07-18 08:34:40.811000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 10:02:22.242000-05:00              23     1
# 1 2017-07-18 08:34:47.225000-05:00              23     3
# 2
# MDS-UPDRS #11: Rest Tremor
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                     EventType             Start Timestamp (ms)  \
# 0  MDS-UPDRS #11: Rest Tremor 2017-07-07 08:35:30.810000-05:00
# 1  MDS-UPDRS #11: Rest Tremor 2017-07-18 08:34:59.976000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:35:39.710000-05:00              19     1
# 1 2017-07-18 08:35:13.727000-05:00              19     3
# 2
# Motor #1: Standing
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#             EventType             Start Timestamp (ms)  \
# 0  Motor #1: Standing 2017-07-07 08:39:05.605000-05:00
# 1  Motor #1: Standing 2017-07-07 09:24:35.244000-05:00
# 2  Motor #1: Standing 2017-07-07 10:04:33.994000-05:00
# 3  Motor #1: Standing 2017-07-07 10:35:46.772000-05:00
# 4  Motor #1: Standing 2017-07-07 11:01:56.519000-05:00
# 5  Motor #1: Standing 2017-07-07 11:26:29.143000-05:00
# 6  Motor #1: Standing 2017-07-18 08:53:37.779000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:39:37.591000-05:00              11     1
# 1 2017-07-07 09:25:15.969000-05:00              11     2
# 2 2017-07-07 10:05:08.891000-05:00              11     3
# 3 2017-07-07 10:36:21.997000-05:00              11     4
# 4 2017-07-07 11:02:29.912000-05:00              11     5
# 5 2017-07-07 11:27:05.632000-05:00              11     6
# 6 2017-07-18 08:54:17.856000-05:00              11     7
# 7
# Motor #2: Walking
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#            EventType             Start Timestamp (ms)  \
# 0  Motor #2: Walking 2017-07-07 08:39:58.834000-05:00
# 1  Motor #2: Walking 2017-07-07 09:25:27.990000-05:00
# 2  Motor #2: Walking 2017-07-07 10:05:19.061000-05:00
# 3  Motor #2: Walking 2017-07-07 10:36:29.081000-05:00
# 4  Motor #2: Walking 2017-07-07 11:02:34.508000-05:00
# 5  Motor #2: Walking 2017-07-07 11:27:12.979000-05:00
# 6  Motor #2: Walking 2017-07-18 08:54:25.711000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:40:36.513000-05:00              18     1
# 1 2017-07-07 09:26:03.141000-05:00              18     2
# 2 2017-07-07 10:05:52.424000-05:00              18     3
# 3 2017-07-07 10:37:03.925000-05:00              18     4
# 4 2017-07-07 11:03:10.327000-05:00              18     5
# 5 2017-07-07 11:27:41.432000-05:00              18     6
# 6 2017-07-18 08:55:02.169000-05:00              18     7
# 7
# Motor #3: Walking while Counting
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                           EventType             Start Timestamp (ms)  \
# 0  Motor #3: Walking while Counting 2017-07-07 08:40:56.580000-05:00
# 1  Motor #3: Walking while Counting 2017-07-07 09:26:15.624000-05:00
# 2  Motor #3: Walking while Counting 2017-07-07 10:05:58.207000-05:00
# 3  Motor #3: Walking while Counting 2017-07-07 10:37:10.480000-05:00
# 4  Motor #3: Walking while Counting 2017-07-07 11:03:17.746000-05:00
# 5  Motor #3: Walking while Counting 2017-07-07 11:27:48.764000-05:00
# 6  Motor #3: Walking while Counting 2017-07-18 08:55:06.382000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:41:31.995000-05:00               8     1
# 1 2017-07-07 09:26:49.754000-05:00               8     2
# 2 2017-07-07 10:06:29.911000-05:00               8     3
# 3 2017-07-07 10:37:41.059000-05:00               8     4
# 4 2017-07-07 11:03:47.073000-05:00               8     5
# 5 2017-07-07 11:28:29.266000-05:00               8     6
# 6 2017-07-18 08:55:39.372000-05:00               8     7
# 7
# Motor #4: Finger to Nose
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                   EventType             Start Timestamp (ms)  \
# 0  Motor #4: Finger to Nose 2017-07-07 08:42:15.413000-05:00
# 1  Motor #4: Finger to Nose 2017-07-07 08:42:58.405000-05:00
# 2  Motor #4: Finger to Nose 2017-07-07 09:27:07.805000-05:00
# 3  Motor #4: Finger to Nose 2017-07-07 09:27:49.963000-05:00
# 4  Motor #4: Finger to Nose 2017-07-07 10:06:47.077000-05:00
# 5  Motor #4: Finger to Nose 2017-07-07 10:37:54.591000-05:00
# 6  Motor #4: Finger to Nose 2017-07-07 11:03:59.455000-05:00
# 7  Motor #4: Finger to Nose 2017-07-07 11:28:39.217000-05:00
# 8  Motor #4: Finger to Nose 2017-07-18 08:55:57.849000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:42:50.474000-05:00              12     1
# 1 2017-07-07 08:43:30.276000-05:00              12     2
# 2 2017-07-07 09:27:42.171000-05:00              12     3
# 3 2017-07-07 09:28:22.483000-05:00              12     4
# 4 2017-07-07 10:08:00.993000-05:00              12     5
# 5 2017-07-07 10:39:04.961000-05:00              12     6
# 6 2017-07-07 11:05:09.237000-05:00              12     7
# 7 2017-07-07 11:29:47.849000-05:00              12     8
# 8 2017-07-18 08:56:36.754000-05:00              12     9
# 9
# Motor #5: Alternating Hand Movements
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                               EventType             Start Timestamp (ms)  \
# 0  Motor #5: Alternating Hand Movements 2017-07-07 08:43:45.831000-05:00
# 1  Motor #5: Alternating Hand Movements 2017-07-07 09:28:31.508000-05:00
# 2  Motor #5: Alternating Hand Movements 2017-07-07 10:08:12.780000-05:00
# 3  Motor #5: Alternating Hand Movements 2017-07-07 10:39:11.001000-05:00
# 4  Motor #5: Alternating Hand Movements 2017-07-07 10:39:51.207000-05:00
# 5  Motor #5: Alternating Hand Movements 2017-07-07 11:05:15.911000-05:00
# 6  Motor #5: Alternating Hand Movements 2017-07-07 11:29:54.838000-05:00
# 7  Motor #5: Alternating Hand Movements 2017-07-18 08:56:40.691000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:44:57.295000-05:00              14     1
# 1 2017-07-07 09:29:42.996000-05:00              14     2
# 2 2017-07-07 10:09:24.574000-05:00              14     3
# 3 2017-07-07 10:39:45.261000-05:00              14     4
# 4 2017-07-07 10:40:22.084000-05:00              14     5
# 5 2017-07-07 11:06:22.974000-05:00              14     6
# 6 2017-07-07 11:30:57.742000-05:00              14     7
# 7 2017-07-18 08:57:18.203000-05:00              14     8
# 8
# Motor #6: Sit to Stand
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                 EventType             Start Timestamp (ms)  \
# 0  Motor #6: Sit to Stand 2017-07-07 08:45:23.853000-05:00
# 1  Motor #6: Sit to Stand 2017-07-07 09:29:49.041000-05:00
# 2  Motor #6: Sit to Stand 2017-07-07 10:09:30.569000-05:00
# 3  Motor #6: Sit to Stand 2017-07-07 10:41:46.922000-05:00
# 4  Motor #6: Sit to Stand 2017-07-07 11:06:29.910000-05:00
# 5  Motor #6: Sit to Stand 2017-07-07 11:31:04.410000-05:00
# 6  Motor #6: Sit to Stand 2017-07-18 08:57:25.726000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:45:32.990000-05:00              16     1
# 1 2017-07-07 09:30:00.350000-05:00              16     2
# 2 2017-07-07 10:09:39.986000-05:00              16     3
# 3 2017-07-07 10:41:55.139000-05:00              16     4
# 4 2017-07-07 11:06:38.771000-05:00              16     5
# 5 2017-07-07 11:31:14.523000-05:00              16     6
# 6 2017-07-18 08:57:36.353000-05:00              16     7
# 7
# Motor #7: Drawing on Paper
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                     EventType             Start Timestamp (ms)  \
# 0  Motor #7: Drawing on Paper 2017-07-07 08:46:23.835000-05:00
# 1  Motor #7: Drawing on Paper 2017-07-07 09:30:37.894000-05:00
# 2  Motor #7: Drawing on Paper 2017-07-07 10:10:05.632000-05:00
# 3  Motor #7: Drawing on Paper 2017-07-07 10:42:16.913000-05:00
# 4  Motor #7: Drawing on Paper 2017-07-07 11:06:52.639000-05:00
# 5  Motor #7: Drawing on Paper 2017-07-07 11:31:22.550000-05:00
# 6  Motor #7: Drawing on Paper 2017-07-18 08:57:41.596000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:47:09.448000-05:00               2     1
# 1 2017-07-07 09:31:13.299000-05:00               2     2
# 2 2017-07-07 10:10:39.230000-05:00               2     3
# 3 2017-07-07 10:42:51.403000-05:00               2     4
# 4 2017-07-07 11:07:26.589000-05:00               2     5
# 5 2017-07-07 11:31:58.580000-05:00               2     6
# 6 2017-07-18 08:58:13.702000-05:00               2     7
# 7
# Motor #8: Typing on a Computer
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                         EventType             Start Timestamp (ms)  \
# 0  Motor #8: Typing on a Computer 2017-07-07 08:47:57.442000-05:00
# 1  Motor #8: Typing on a Computer 2017-07-07 09:31:24.138000-05:00
# 2  Motor #8: Typing on a Computer 2017-07-07 10:10:46.181000-05:00
# 3  Motor #8: Typing on a Computer 2017-07-07 10:42:56.779000-05:00
# 4  Motor #8: Typing on a Computer 2017-07-07 11:07:32.191000-05:00
# 5  Motor #8: Typing on a Computer 2017-07-07 11:32:04.919000-05:00
# 6  Motor #8: Typing on a Computer 2017-07-18 08:58:29.563000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:48:30.944000-05:00              20     1
# 1 2017-07-07 09:32:00.112000-05:00              20     2
# 2 2017-07-07 10:11:20.354000-05:00              20     3
# 3 2017-07-07 10:43:30.334000-05:00              20     4
# 4 2017-07-07 11:08:07.695000-05:00              20     5
# 5 2017-07-07 11:32:39.888000-05:00              20     6
# 6 2017-07-18 08:59:14.629000-05:00              20     7
# 7
# Motor #9: Nuts and Bolts
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                   EventType             Start Timestamp (ms)  \
# 0  Motor #9: Nuts and Bolts 2017-07-07 08:49:11.584000-05:00
# 1  Motor #9: Nuts and Bolts 2017-07-07 09:32:14.141000-05:00
# 2  Motor #9: Nuts and Bolts 2017-07-07 10:11:29.910000-05:00
# 3  Motor #9: Nuts and Bolts 2017-07-07 10:43:36.756000-05:00
# 4  Motor #9: Nuts and Bolts 2017-07-07 11:08:13.265000-05:00
# 5  Motor #9: Nuts and Bolts 2017-07-07 11:32:45.127000-05:00
# 6  Motor #9: Nuts and Bolts 2017-07-18 08:59:22.674000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:49:46.814000-05:00              21     1
# 1 2017-07-07 09:32:51.483000-05:00              21     2
# 2 2017-07-07 10:12:04.599000-05:00              21     3
# 3 2017-07-07 10:44:08.237000-05:00              21     4
# 4 2017-07-07 11:08:44.299000-05:00              21     5
# 5 2017-07-07 11:33:19.023000-05:00              21     6
# 6 2017-07-18 09:00:02.513000-05:00              21     7
# 7
# Motor #10: Drinking Water
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                    EventType             Start Timestamp (ms)  \
# 0  Motor #10: Drinking Water 2017-07-07 08:50:31.740000-05:00
# 1  Motor #10: Drinking Water 2017-07-07 09:33:00.350000-05:00
# 2  Motor #10: Drinking Water 2017-07-07 10:12:11.129000-05:00
# 3  Motor #10: Drinking Water 2017-07-07 10:44:17.630000-05:00
# 4  Motor #10: Drinking Water 2017-07-07 11:08:49.600000-05:00
# 5  Motor #10: Drinking Water 2017-07-07 11:33:25.859000-05:00
# 6  Motor #10: Drinking Water 2017-07-18 09:00:11.205000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:51:09.745000-05:00               0     1
# 1 2017-07-07 09:33:29.736000-05:00               0     2
# 2 2017-07-07 10:12:33.880000-05:00               0     3
# 3 2017-07-07 10:44:41.872000-05:00               0     4
# 4 2017-07-07 11:09:15.128000-05:00               0     5
# 5 2017-07-07 11:33:49.522000-05:00               0     6
# 6 2017-07-18 09:00:41.509000-05:00               0     7
# 7
# Motor #11: Organizing Folder
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                       EventType             Start Timestamp (ms)  \
# 0  Motor #11: Organizing Folder 2017-07-07 08:51:48.033000-05:00
# 1  Motor #11: Organizing Folder 2017-07-07 09:33:46.142000-05:00
# 2  Motor #11: Organizing Folder 2017-07-07 10:12:56.628000-05:00
# 3  Motor #11: Organizing Folder 2017-07-07 10:44:46.730000-05:00
# 4  Motor #11: Organizing Folder 2017-07-07 11:09:29.435000-05:00
# 5  Motor #11: Organizing Folder 2017-07-07 11:34:00.716000-05:00
# 6  Motor #11: Organizing Folder 2017-07-18 09:01:00.143000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:52:33.323000-05:00               6     1
# 1 2017-07-07 09:34:09.305000-05:00               6     2
# 2 2017-07-07 10:13:24.361000-05:00               6     3
# 3 2017-07-07 10:45:25.547000-05:00               6     4
# 4 2017-07-07 11:09:58.748000-05:00               6     5
# 5 2017-07-07 11:34:28.406000-05:00               6     6
# 6 2017-07-18 09:01:27.331000-05:00               6     7
# 7
# Motor #12: Folding Towels
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#                    EventType             Start Timestamp (ms)  \
# 0  Motor #12: Folding Towels 2017-07-07 08:53:13.127000-05:00
# 1  Motor #12: Folding Towels 2017-07-07 09:34:19.296000-05:00
# 2  Motor #12: Folding Towels 2017-07-07 10:13:28.885000-05:00
# 3  Motor #12: Folding Towels 2017-07-07 10:45:31.056000-05:00
# 4  Motor #12: Folding Towels 2017-07-07 11:10:03.949000-05:00
# 5  Motor #12: Folding Towels 2017-07-07 11:34:32.573000-05:00
# 6  Motor #12: Folding Towels 2017-07-18 09:01:31.252000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:53:45.441000-05:00               9     1
# 1 2017-07-07 09:34:39.994000-05:00               9     2
# 2 2017-07-07 10:13:48.523000-05:00               9     3
# 3 2017-07-07 10:45:49.171000-05:00               9     4
# 4 2017-07-07 11:10:28.944000-05:00               9     5
# 5 2017-07-07 11:34:55.818000-05:00               9     6
# 6 2017-07-18 09:01:53.927000-05:00               9     7
# 7
# Motor #13: Sitting
#                       Sensor:
# 0         anterior_thigh_left
# 1        anterior_thigh_right
# 2   distal_lateral_shank_left
# 3  distal_lateral_shank_right
# 4            dorsal_hand_left
# 5           dorsal_hand_right
# 6       flexor_digitorum_left
# 7      flexor_digitorum_right
# 8                medial_chest
# 9                      sacrum
#             EventType             Start Timestamp (ms)  \
# 0  Motor #13: Sitting 2017-07-07 08:53:59.937000-05:00
# 1  Motor #13: Sitting 2017-07-07 09:34:51.779000-05:00
# 2  Motor #13: Sitting 2017-07-07 10:13:58.350000-05:00
# 3  Motor #13: Sitting 2017-07-07 10:45:55.054000-05:00
# 4  Motor #13: Sitting 2017-07-07 11:10:34.242000-05:00
# 5  Motor #13: Sitting 2017-07-07 11:35:02.848000-05:00
# 6  Motor #13: Sitting 2017-07-18 09:01:59.749000-05:00
#
#                Stop Timestamp (ms)  EventType_Rank Cycle
# 0 2017-07-07 08:54:33.423000-05:00               5     1
# 1 2017-07-07 09:35:26.741000-05:00               5     2
# 2 2017-07-07 10:14:33.356000-05:00               5     3
# 3 2017-07-07 10:46:26.465000-05:00               5     4
# 4 2017-07-07 11:11:06.780000-05:00               5     5
# 5 2017-07-07 11:35:40.273000-05:00               5     6
# 6 2017-07-18 09:03:17.181000-05:00               5     7
# 7

# %%
def absent_timestamps(df, absent):
# Inputs:  df - original annotation dataframe
#          absent - dataframe of absent (missing or skipped) activity labels
#
# Outputs: df_new - updated dataframe with placeholder activities to indicate
#                   the activity was missing
    for labels in missing:



def merge_timestamps(df, merge):
# Inputs:  df - original annotation dataframe
#          merge - dataframe of activities to merge
#
# Outputs: df_new - updated dataframe with merged timestampes per activities
    for labels in merge:
    

    
def split_timestamps(df, split):
# Inputs:  df - original annotation dataframe
#          split - dataframe of activity labels needed to be split
#
# Outputs: df_new - updated dataframe with split activities
    for labels in split:
